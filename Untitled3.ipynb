# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools
from sklearn.metrics import confusion_matrix
import seaborn as sns
from scipy import stats
import scipy
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import shapiro
from scipy.stats import levene
from scipy import stats
from scipy.stats import f_oneway

# %%
class Information():

    def __init__(self):
        
        print("Information object created")
        self.df = pd.read_csv("hmelq.csv")
        
    def info(self): 
        
         
        print(self.df.head())
        print("--------------------")
        print(self.df.sample(30))#random row and columns
        print("--------------------")
        print(self.df.describe())#give the count,mean and data number
        print("--------------------")
        print(self.df.info())#give the non values
        print("------Drop the rows where at least one element is missing----------")
        print(self.df.dropna().head())##nan değerleri temizlenmesi,Drop the rows where at least one element is missing:
        # badlerin dağılımlarının sayısı
          #tb.index=["0=False","1=True"]
        self.tb1=pd.crosstab(index=self.df["bad"],columns="Count")
        print("------Distribution number of Bad----------")
        print(self.tb1)##nan değerleri temizlenmesi,Drop the rows where at least one element is missing:
        print("------Distribution number of the job according to bad----------")
        
        self.tb_bad_job=pd.crosstab(index=self.df["job"],columns=self.df["bad"],margins=True)
        print(self.tb_bad_job)
        
        
#        print(self.tb1)##nan değerleri temizlenmesi,Drop the rows where at least one element is missing:
#jobların 0 ve 1 e göre dağılımları
#tb_bad_job=pd.crosstab(index=df["job"],columns=df["bad"],margins=True)
#tb_bad_job
#This compares the index and column to get the count.
class Visualizer:
    
        def __init__(self):
            print("Visualizer object created!")  
            self.df = pd.read_csv("hmelq.csv")
       
                
        def histogram(self): 

        #tüm nümeriklerin histogram grafikleri
             for i in self.df.columns:
                 if (i!='reason' and i!='job' and i!='bad'):
                        plt.figure()
                        plt.hist(self.df[i],bins=100,color="orange")
                        plt.title("Histogram of " + i)
        def hist(self): 
            pd.DataFrame(self.df).plot.hist()
            plt.show()
            
        def corelation(self): 
            corr = self.df.corr()
            print(corr)  
            fig, ax=plt.subplots(figsize=(10,8))
            colormap =sns.diverging_palette(220,10,as_cmap=True)
            sns.heatmap(corr,cmap=colormap, annot=True, fmt='.2f')
            plt.xticks(range(len(corr.columns)),corr.columns)
            plt.yticks(range(len(corr.columns)),corr.columns)
            plt.show() 
            
            
            
    
class PreprocessStrategy():
 
       def __init__(self):
        print("done")  
        self.df = pd.read_csv("hmelq.csv")
    ##tüm nümerik değerlerde bad'in 0 ve 1 olduğu durumlar için shapiro testi
    
       def gaussiandist(self): 
        grps=pd.unique(self.df.bad.values)
        grps
        alpha=0.05
        for i in self.df.columns:
                if (i!='reason' and i!='job' and i!='bad'): #i'nin reason, job, ve bad olmadığı durumlarda çalış 
                    for name in grps:
                        stat,p=shapiro(self.df[i][self.df['bad']==name])
                        print(i)
                        print(name,"için İstatistik değeri: %.3f, p değeri =" %stat , p)        
                        if p >alpha:
                             print('Orneklem Normal (Gaussian) dağılımdan gelmektedir')  
                        else:
                             print('Orneklem Normal (Gaussian) dağılım gostermemektedir')

# %%
#result=Information()
result=PreprocessStrategy()
result.lev()
# Out:
# done
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-143-56ad1954c578> in <module>
#       1 #result=Information()
#       2 result=PreprocessStrategy()
# ----> 3 result.lev()
#
# AttributeError: 'PreprocessStrategy' object has no attribute 'lev'

# %%
result=Information()
result.info()
# Out:
# Information object created
#    bad   loan   mortdue     value   reason  job   yoj  derog  delinq   clage  \
# 0    0  81200   18834.0  108355.0  HomeImp  NaN  28.0    0.0     0.0  139.14
# 1    0  12600  103960.0  127384.0  DebtCon  NaN   2.0    0.0     0.0  129.02
# 2    0  18000   46865.0   61266.0  DebtCon  NaN   5.0    0.0     0.0  102.59
# 3    0  10300   57676.0   71027.0  DebtCon  NaN  19.0    0.0     0.0  157.52
# 4    0   9400   56508.0   78358.0  DebtCon  NaN  17.0    0.0     0.0  141.93
#
#    ninq  clno  debtinc
# 0   0.0  14.0   34.042
# 1   0.0  25.0   34.479
# 2   2.0   9.0   26.354
# 3   1.0  11.0   33.992
# 4   0.0  11.0   32.327
# --------------------
#       bad   loan   mortdue     value   reason     job   yoj  derog  delinq  \
# 2799    0  25900  152071.0  185893.0  HomeImp    Self   0.0    0.0     0.0
# 305     0  11800   57760.0   65535.0  DebtCon     Mgr  11.0    0.0     0.0
# 1013    0  13900   71425.0   81012.0  DebtCon   Other   2.0    0.0     0.0
# 3256    1  42000   65889.0  125000.0  HomeImp   Other  10.0    0.0     0.0
# 551     0  20400   44746.0   63433.0  DebtCon  Office   5.0    0.0     0.0
# 3426    1  13900  144263.0  167164.0  DebtCon  ProfEx   8.0    2.0     6.0
# 386     0  21300  143676.0  181960.0  HomeImp     Mgr   8.0    0.0     0.0
# 307     0  11900   78959.0  104371.0  DebtCon     Mgr   1.0    0.0     0.0
# 2655    0   6500   78741.0   90599.0  DebtCon  ProfEx   0.0    NaN     NaN
# 2917    1  13700   59012.0   81465.0  DebtCon     Mgr  12.0    0.0     0.0
# 595     0  16600   69644.0  100411.0  DebtCon  Office   0.0    0.0     0.0
# 2298    0  14700   35164.0   68061.0  DebtCon  ProfEx   5.0    0.0     0.0
# 3418    1  23300   71734.0  100072.0  DebtCon  ProfEx   6.0    0.0     7.0
# 3002    1  18800   73396.0  137076.0  DebtCon  Office  18.0    0.0     1.0
# 1589    0  12900   50636.0   57838.0  DebtCon   Other   0.0    1.0     0.0
# 2496    0  18400   63569.0   95729.0  HomeImp  ProfEx  23.0    0.0     0.0
# 1249    0  42000   21314.0   68047.0  DebtCon   Other  21.0    0.0     0.0
# 2910    1  20000  142500.0  190000.0  DebtCon     Mgr   0.2    2.0     4.0
# 2001    0  16500       NaN   42894.0  HomeImp   Other   1.0    0.0     0.0
# 1043    0  11500   53151.0   71645.0  HomeImp   Other   7.0    0.0     0.0
# 622     0  19700   60999.0   89841.0  DebtCon  Office   0.0    0.0     0.0
# 2240    0  15200   47200.0   74510.0  DebtCon  ProfEx  17.0    0.0     0.0
# 183     0  23000  108464.0  155821.0  DebtCon     Mgr  16.0    0.0     0.0
# 2170    0  26800  149729.0  183027.0  DebtCon  ProfEx   7.0    0.0     0.0
# 254     0  10300   82889.0   97189.0  DebtCon     Mgr   2.0    0.0     0.0
# 134     0  23900       NaN  151738.0      NaN     NaN   NaN    NaN     NaN
# 2861    0  50800       NaN   86207.0  HomeImp    Self   9.0    0.0     0.0
# 249     0  23600   96452.0  125277.0  HomeImp     Mgr  11.0    0.0     0.0
non-null   float64
# dtypes: float64(9), int64(2), object(2)
# memory usage: 363.3+ KB
# None
# ------Drop the rows where at least one element is missing----------
#      bad   loan   mortdue     value   reason  job   yoj  derog  delinq  \
# 153    0  18200   94727.0  136877.0  DebtCon  Mgr  15.0    0.0     0.0
# 154    0  21700   79240.0   96784.0  DebtCon  Mgr   5.0    0.0     0.0
# 155    0  34100  241931.0   36486.0  DebtCon  Mgr   1.0    0.0     2.0
# 156    0   8400   62989.0   76718.0  HomeImp  Mgr   3.0    0.0     2.0
# 157    0  17400   25859.0   43684.0  DebtCon  Mgr  16.0    1.0     0.0
#
#       clage  ninq  clno  debtinc
# 153  168.96   2.0  26.0   36.056
# 154   64.51   6.0  24.0   38.079
# 155  196.01   3.0  50.0   42.459
# 156  131.47   0.0  22.0   29.200
# 157   95.36   1.0  17.0   27.108
# ------Distribution number of Bad----------
# col_0  Count
# bad
# 0       2863
# 1        713
# ------Distribution number of the job according to bad----------
# bad        0    1   All
# job
# Mgr      354  107   461
# Office   494   75   569
# Other   1099  332  1431
# ProfEx   639  128   767
# Sales     43   23    66
# Self      81   34   115
# All     2710  699  3409

# %%
# Out:
# Information object created
#    bad   loan   mortdue     value   reason  job   yoj  derog  delinq   clage  \
# 0    0  81200   18834.0  108355.0  HomeImp  NaN  28.0    0.0     0.0  139.14
# 1    0  12600  103960.0  127384.0  DebtCon  NaN   2.0    0.0     0.0  129.02
# 2    0  18000   46865.0   61266.0  DebtCon  NaN   5.0    0.0     0.0  102.59
# 3    0  10300   57676.0   71027.0  DebtCon  NaN  19.0    0.0     0.0  157.52
# 4    0   9400   56508.0   78358.0  DebtCon  NaN  17.0    0.0     0.0  141.93
#
#    ninq  clno  debtinc
# 0   0.0  14.0   34.042
# 1   0.0  25.0   34.479
# 2   2.0   9.0   26.354
# 3   1.0  11.0   33.992
# 4   0.0  11.0   32.327
# --------------------
#       bad   loan   mortdue     value   reason     job   yoj  derog  delinq  \
# 2916    1   6300   65875.0   76000.0  DebtCon     Mgr   0.8    2.0     0.0
# 2610    0  22600   59050.0   99152.0  DebtCon  ProfEx   0.0    0.0     0.0
# 3084    1   2900    7750.0   67996.0  HomeImp   Other  16.0    3.0     0.0
# 1951    0   5000   73126.0   87500.0  DebtCon   Other   1.0    0.0     0.0
# 3560    1  32000   92400.0  215000.0      NaN    Self   2.5    1.0     3.0
# 1670    0  15600   49151.0   62005.0  DebtCon   Other   4.0    0.0     0.0
# 3160    1  11600   57200.0   72500.0  DebtCon   Other   5.0    0.0     0.0
# 1093    0  12500   56960.0   69014.0  DebtCon   Other   4.0    0.0     0.0
# 788     0  12100   68941.0   75029.0  HomeImp  Office  14.0    0.0     0.0
# 281     0  20800   56597.0   79582.0  DebtCon     Mgr   9.0    1.0     0.0
# 65      0  14600   59658.0   80384.0  DebtCon     NaN   8.0    NaN     NaN
# 3442    1  15000  125000.0  177100.0  HomeImp  ProfEx  10.0    3.0     1.0
# 744     0  19000  130291.0  168187.0  DebtCon  Office   3.0    0.0     0.0
# 760     0   7000   73873.0  111781.0  DebtCon  Office   0.0    0.0     0.0
# max       1.000000  89900.000000  399550.000000  850000.000000    41.000000
#
#              derog       delinq        clage         ninq         clno  \
# count  3149.000000  3225.000000  3397.000000  3273.000000  3443.000000
# mean      0.261670     0.432558   179.832529     1.186373    21.507116
# std       0.865178     1.099230    87.066198     1.728723    10.167490
# min       0.000000     0.000000     0.490000     0.000000     0.000000
# 25%       0.000000     0.000000   115.600000     0.000000    15.000000
# 50%       0.000000     0.000000   173.640000     1.000000    20.000000
# 75%       0.000000     0.000000   230.710000     2.000000    26.000000
# max      10.000000    15.000000  1168.230000    17.000000    71.000000
#
#            debtinc
# count  2809.000000
# mean     33.831737
# std       9.061837
# min       0.720000
# 25%      29.140000
# 50%      34.747000
# 75%      38.940000
# max     203.312000
# --------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3576 entries, 0 to 3575
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   bad      3576 non-null   int64
#  1   loan     3576 non-null   int64
#  2   mortdue  3262 non-null   float64
#  3   value    3512 non-null   float64
#  4   reason   3429 non-null   object
#  5   job      3409 non-null   object
#  6   yoj      3264 non-null   float64
#  7   derog    3149 non-null   float64
#  8   delinq   3225 non-null   float64
#  9   clage    3397 non-null   float64
#  10  ninq     3273 non-null   float64
#  11  clno     3443 non-null   float64
#  12  debtinc  2809 non-null   float64
# dtypes: float64(9), int64(2), object(2)
# memory usage: 363.3+ KB
# None
# ------Drop the rows where at least one element is missing----------
#      bad   loan   mortdue     value   reason  job   yoj  derog  delinq  \
# 153    0  18200   94727.0  136877.0  DebtCon  Mgr  15.0    0.0     0.0
# 154    0  21700   79240.0   96784.0  DebtCon  Mgr   5.0    0.0     0.0
# 155    0  34100  241931.0   36486.0  DebtCon  Mgr   1.0    0.0     2.0
# 156    0   8400   62989.0   76718.0  HomeImp  Mgr   3.0    0.0     2.0
# 157    0  17400   25859.0   43684.0  DebtCon  Mgr  16.0    1.0     0.0
#
#       clage  ninq  clno  debtinc
# 153  168.96   2.0  26.0   36.056
# 154   64.51   6.0  24.0   38.079
# 155  196.01   3.0  50.0   42.459
# 156  131.47   0.0  22.0   29.200
# 157   95.36   1.0  17.0   27.108
# ------Distribution number of Bad----------
# col_0  Count
# bad
# 0       2863
# 1        713
# ------Distribution number of the job according to bad----------
# bad        0    1   All
# job
# Mgr      354  107   461
# Office   494   75   569
# Other   1099  332  1431
# ProfEx   639  128   767
# Sales     43   23    66
# Self      81   34   115
# All     2710  699  3409

# %%
result=Information()
result.sample()
# Out:
# Information object created
# orneklem:       bad   loan   mortdue      value   reason     job   yoj  derog  delinq  \
# 2914    1  22300   75600.0  102000.00  DebtCon     Mgr   5.0    0.0     1.0
# 3513    1  26000   79714.0        NaN  DebtCon  ProfEx   1.0    0.0     4.0
# 16      0  10200   46140.0   56206.00  DebtCon     NaN   8.0    1.0     0.0
# 2374    0  22400   40605.0   76986.00  DebtCon  ProfEx   9.0    0.0     0.0
# 1940    0   6000   69876.0   94394.07  HomeImp   Other   0.0    0.0     1.0
# 76      0  21600  106308.0  147378.00  HomeImp     NaN   NaN    NaN     NaN
# 28      0  79200   22940.0  110114.00  HomeImp     NaN  28.0    0.0     1.0
# 2271    0  33600  233630.0  284049.00  DebtCon  ProfEx   4.0    0.0     0.0
# 1847    0  14400   45516.0   63924.00  DebtCon   Other   NaN    0.0     0.0
# 2716    0  37600  141000.0  200300.00  HomeImp  ProfEx   5.0    0.0     0.0
# 2423    0   7300  139348.0  205981.00  DebtCon  ProfEx   1.0    0.0     0.0
# 1363    0  12600   67860.0  103426.00  DebtCon   Other   9.0    0.0     0.0
# 1881    0  16000   62200.0   89200.00  DebtCon   Other   1.9    0.0     0.0
# 2936    1  17000   54218.0   75000.00  DebtCon     Mgr   5.0    1.0     0.0
# 2251    0  21200  103264.0  148968.00  HomeImp  ProfEx   8.0    0.0     0.0
# 567     0  18600   20915.0   40098.00      NaN  Office   2.0    0.0     0.0
# 1876    0   7900   42400.0   53000.00  DebtCon   Other   2.0    0.0     1.0
# 3177    1   2300   37626.0   46200.00  HomeImp   Other   3.0    0.0     1.0
# 718     0   7900   44690.0   45841.00  DebtCon  Office  10.0    0.0     0.0
# 2852    0  21400   88147.0  115000.00  DebtCon    Self   3.0    0.0     0.0
# 1735    0  18700   50354.0   79011.00  DebtCon   Other   1.0    NaN     1.0
# 1999    0  26500       NaN   61089.00  DebtCon   Other  27.0    0.0     0.0
# 368     0  35600   20552.0   46697.00  DebtCon     Mgr   7.0    0.0     0.0
# 2443    0  27900   73630.0  106757.00  DebtCon  ProfEx  11.0    0.0     0.0
# 1878    0  15000   94705.0  114400.00  DebtCon   Other   9.0    0.0     0.0
# 3214    1   4000   55000.0   59000.00  DebtCon   Other  12.0    2.0     0.0
# 1875    0  21000   42000.0   67000.00  DebtCon   Other   7.0    0.0     0.0
# 2431    0  11000   21780.0   85505.00  HomeImp  ProfEx  19.0    0.0     0.0
# 27      0  81400   21041.0  111304.00  HomeImp     NaN  26.0    0.0     0.0
# 2373    0  26700  146193.0  185200.00  DebtCon  ProfEx  11.0    0.0     0.0
#
#        clage  ninq  clno  debtinc
# 2914   64.93   2.0  28.0      NaN
# 3513  125.77   0.0  23.0      NaN
# 16    115.78   1.0  25.0   22.314
# 2374  276.28   0.0  19.0   39.730
# 1940  179.57   0.0  32.0      NaN
# 76       NaN   NaN   NaN   39.138
# 28    144.62   0.0  13.0   32.367
# 2271  218.99   0.0  30.0   14.072
# 1847  109.33   1.0  19.0   40.872
# 2716  145.63   0.0  31.0      NaN
# 2423   60.42   2.0  22.0   36.812
# 1363  202.15   0.0  20.0   18.348
# 1881  176.53   1.0  31.0      NaN
# 2936  177.50   6.0  35.0      NaN
# 2251  161.86   1.0  22.0   34.549
# 567   213.45   0.0  16.0   40.250
# 1876   95.37   0.0  20.0      NaN
# 3177  122.27   1.0  14.0      NaN
# 718   185.62   0.0  22.0   32.286
# 2852  213.23   2.0  27.0      NaN
# 1735  290.83   1.0  10.0   35.139
# 1999  144.19   0.0   9.0   22.814
# 368    45.14   0.0   6.0   36.063
# 2443  282.76   1.0  32.0   38.267
# 1878  300.27   2.0  19.0      NaN
# 3214  146.10   0.0  22.0      NaN
# 1875   66.63   2.0  19.0      NaN
# 2431  240.68   0.0  10.0   24.404
# 27    146.32   0.0  14.0   32.131
# 2373  156.23   0.0  36.0   39.210
